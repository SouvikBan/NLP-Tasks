# %%
import sys
from operator import itemgetter
from copy import deepcopy


def get_corpus(filename):
    '''load corpus located at filename'''
    with open(filename, 'r') as myfile:
        corpus = [next(myfile) for x in range(1000)]
    
    if VERBOSE:
        print(corpus, file=sys.stderr)
    return corpus

def get_words(en_corpus, hi_corpus):
    
    def source_words(lang):
        corpus = en_corpus if lang == 'en' else hi_corpus
        for sentence in corpus:
            for word in sentence.split():
                yield word
    
    return {lang: set(source_words(lang)) for lang in ('en', 'hi')} 

def summarize_results(trans_prob):
    return {
        k: sorted(v.items(), key=itemgetter(1), reverse=True)[0][0] for (k, v) in trans_prob.items()
    }

def train_iteration(en_corpus, hi_corpus, words, s_total, prev_trans_prob):
    
    trans_prob = deepcopy(prev_trans_prob)

    count = {word_en: {word_hi: 0 for word_hi in words['hi']} for word_en in words['en']} #count(en|hi) = 0

    total = {word_hi: 0 for word_hi in words['hi']} #total(hi) = 0 

    for (ens, his) in [(en_corpus[i].split(), hi_corpus[i].split()) for i in range(1000)]:
        for en in ens:
            s_total[en] = 0

            for hi in his:
                s_total[en] += trans_prob[en][hi]

        for en in ens:
            for hi in his:
                count[en][hi] += (trans_prob[en][hi] / s_total[en])
                total[hi] += trans_prob[en][hi] / s_total[en]

    for hi in words['hi']:
        for en in words['en']:
            trans_prob[en][hi] = count[en][hi] / total[hi]

    return trans_prob


if __name__ == '__main__':
    
    en_corpus = get_corpus('./train.en')
    hi_corpus = get_corpus('./train.hi')
    
    words = get_words(en_corpus, hi_corpus)
    
    print(words)
    
    s_total = {word_en: 0 for word_en in words['en']}
    
    #init trans prob(uniform distribution)
    prev_trans_prob = {word_en: {word_hi: 1/len(words['hi']) for word_hi in words['hi']} for word_en in words['en']}

    converged = False
    iterations = 0
    
    while iterations <= 100:
        iterations += 1
        trans_prob = train_iteration(en_corpus, hi_corpus, words, s_total, prev_trans_prob)
        iter_table = summarize_results(trans_prob)
        if converged:
            pass
        prev_trans_prob = trans_prob
        
    print(summarize_results(trans_prob))
# Out:
# {'en': {'last', 'appointed', 'while', 'differences', 'number', 'Nyctalopia', 'paramedical', 'incidence', 'floor', 'mouths', 'else', 'knot', 'sanitation', 'Centre', 'ECCE-IOL', 'or', 'attention', 'National', 'bronchitis', 'above', 'institutes', 'tunnel', 'filtering', 'wound', 'eat', 'extra', 'disease', 'complication', 'highest', 'Population', 'stitch', 'cold', 'Tetanus', 'diagnostic', 'adding', 'precautions', 'giving', 'coughing', '21', 'Absorption', 'related', 'services', 'medical-philosophy', 'microbacterium', 'discolored', 'sent', 'issues', 'reforms', 'distribution', 'service', 'thought', 'measures', 'emotions', 'Oily', 'experienced', 'complains', 'quality', 'power', 'average', 'windpipe', 'Even', 'partners', 'adults', 'works', 'fluids', 'scale', 'vessels', 'nerves', 'secure', 'therefore', 'freckle', 'earliest', 'Mental', 'soda', 'Entamoeba', 'fitted', 'typhoid', 'Satvik', 'Dehradun', 'hysterectomy', 'Special', 'wealth', 'unexpected', 'basically', 'red', 'anemia', 'Fingers', 'waist', 'Tactile', 'shine', 'bone', 'complain', 'actions', 'Initiation', 'dangerous', 'vinegar', 'needed', 'extensive', 'breasts', 'developed', 'affect', 'aware', 'installation', 'less', 'natural', 'original', 'Greek', 'conclude', 'scan', 'gynaecological', 'some', 'step', 'enthusiasm', 'bag', 'Indian', 'immunisation', 'fixed', 'Remember', 'savior', 'Paudi', 'Tuberculosis', 'attempts', 'vaccination', 'cough', 'term', 'months', 'Important', 'proves', '60', 'Medical', 'supply', 'hepatitis-B', 'hand', 'centres', 'encourage', 'head', 'herpes', 'uplifts', 'intoxicating', 'weapon', 'attentiveness', 'itching', 'bite', 'therapies', 'periodic', 'identifying', 'green', 'throat', 'impact', 'saved', 'Sample', 'disability', 'You', 'continuous', 'colleges', 'vegetables', 'empty', 'believes', 'damaged', 'selected', 'alternative', 'Heart', 'rice', 'Chikungunya', 'mood', 'Considering', 'effective', 'Contracted', 'fair', 'supposed', 'such', 'sufficient', 'rejects', 'midwives', 'through', 'wet', 'unacceptance', 'computer', 'Microscopic', 'thigh', 'week', 'species', 'fact', 'eating', 'goal', 'sweet', 'ginger', 'births', '9', 'nine', 'angry', 'tension', 'cervix', 'unborn', 'best', 'pus', 'all', 'Prevention', 'privilege', 'serious', 'chemotherapy', 'same', 'an', 'opening', 'foam', 'shown', 'aggressive', '30', 'incidents', 'Burning', 'iris', 'Cyst', 'correctly', 'safety', 'soft', 'just', 'report', 'single', 'Disorder', 'advancement', 'order', 'prevents', 'taken', 'Uttarakhand', 'Similarly', 'painful', 'hard', 'perotitis', 'United', 'occurring', 'acceptability', 'better', 'under', 'Eurotransplant', 'pots', 'anti', 'Agastyamuni', 'cleaning', 'tip', 'industrial', 'equally', 'breast', 'made', 'suppress', 'Association', 'alcohol', 'fills', 'shivering', 'anyone', 'kurta', 'places', 'advantageous', 'quantity', 'blackboard', 'mark', 'paddy', 'breakfast', 'entering', 'Udham', 'Incurable', 'burn', 'flaviviridae', 'sight', 'emotionally', 'left', 'Cooperate', 'tyres', 'faithful', 'i', 'leiomyoma', 'jaggery', 'arthritis', 'arrowroot', 'alone', 'intimacy', 'see', 'urine', 'seed', 'acacia', 'falls', 'papules', 'oil', 'sitting', 'Historical', 'Method', 'standardized', 'That', 'spots', 'Although', 'radioactive', 'place', 'They', 'causes', 'scheme', 'surgeons', 'fifth', 'unicompartmental', 'open', 'Regular', 'According', 'Europe', 'removing', 'driving', 'headache', 'insecticides', 'anus', 'rotating', 'intact', '39', 'face', 'injections', 'Social', 'salt', 'dengue', 'traveling', 'cup', 'swelling', 'insect', 'second', 'Vegetarianism', '200-300', 'believe', 'DOTS', 'living', 'body', 'reason', 'always', 'motion', 'delirium', 'healer', 'woman', 'afraid', 'indications', 'workers', 'short', 'sign', 'Primary', 'Strokes', '0', 'Eat', 'proved', 'diarrhoea', 'Before', 'Transplanting', 'fenugreek', 'lose', 'sodium', 'corneal', 'Numbness', 'eats', 'themselves', '1976-1981', 'Sexually', 'edible', 'kerosene', 'respectively', 'Benefit', 'platelet', 'Revised', 'pack', 'Eye', 'defect', '-', 'her', 'Toilet', 'got ...
# {'last': 'अन्धापन', 'appointed': 'तैनात', 'while': 'जबकि', 'differences': 'विभिन्नताएँ', 'number': 'संख्या', 'Nyctalopia': 'रतौंधी', 'paramedical': 'पंचायती', 'incidence': 'प्रिवलेस', 'floor': 'खास', 'mouths': 'संकेतों', 'else': 'ब्लडप्रेशर', 'knot': 'गाँठ', 'sanitation': 'Environmental', 'Centre': 'माईक्रोस्कोपिक', 'ECCE-IOL': 'टनल', 'or': 'या', 'attention': 'ध्यान', 'National': 'योजना', 'bronchitis': 'जिनसे', 'above': 'उपरोक्त', 'institutes': 'संस्थानों', 'tunnel': 'टनल', 'filtering': 'प्रयत्\u200dन', 'wound': 'घाव', 'eat': 'सेवन', 'extra': 'दबाव', 'disease': 'बीमारी', 'complication': 'विकृत', 'highest': 'उच्चतम', 'Population': 'पंचायती', 'stitch': 'एन.एस.वी.', 'cold': 'सर्दी', 'Tetanus': 'धूल', 'diagnostic': 'आर.एफ.टी.', 'adding': 'सा', 'precautions': 'क्या-क्या', 'giving': 'देकर', 'coughing': 'खाँसने', '21': '21', 'Absorption': 'Absorption', 'related': 'सम्बन्धित', 'services': 'सेवाओं', 'medical-philosophy': 'चिकित्सा-दर्शन', 'microbacterium': 'माइक्रोबैक्टीरियम', 'discolored': 'चुभन', 'sent': 'प्रस्ताव', 'issues': 'सुनिश्\u200dचित', 'reforms': 'संस्थाएँ', 'distribution': 'सेवाएँ', 'service': 'सेवा', 'thought': 'सोच', 'measures': 'स्तनकैंसर', 'emotions': 'बैचेनी', 'Oily': 'चमक', 'experienced': 'अनुभव', 'complains': 'सा', 'quality': 'कांटेक्ट', 'power': 'शक्ति', 'average': 'पीरियड', 'windpipe': 'स्वॉस', 'Even': '56', 'partners': 'साथियों', 'adults': 'वयस्कों', 'works': 'कार्य', 'fluids': 'द्रव्यों', 'scale': 'वर्षों', 'vessels': 'वाहिनियों', 'nerves': 'नेत्र', 'secure': 'करायी', 'therefore': 'समुदाय', 'freckle': 'चकत्ते', 'earliest': 'इसलिये', 'Mental': 'प्राधिकरण', 'soda': 'चुटकी', 'Entamoeba': 'Entamoeba', 'fitted': 'बैग', 'typhoid': 'टाइफाईड', 'Satvik': 'सात्विक', 'Dehradun': 'देहरादून', 'hysterectomy': 'हिस्टेरेक्टोमी:', 'Special': 'एन.एस.वी.', 'wealth': 'आज्ञा', 'unexpected': 'अनापेक्षित', 'basically': 'मूलतः', 'red': 'लाल', 'anemia': 'अल्पता', 'Fingers': 'अंगुलियाँ', 'waist': 'कमर', 'Tactile': 'स्पर्श', 'shine': 'चमक', 'bone': 'हड्डी', 'complain': 'मूत्र', 'actions': 'खास', 'Initiation': 'शुरूआत', 'dangerous': 'खतरनाक', 'vinegar': 'सीने', 'needed': 'जरूरत', 'extensive': 'उल्लेखनीय', 'breasts': 'स्तनों', 'developed': 'विकसित', 'affect': 'समान', 'aware': 'जागरूक', 'installation': 'पंचायती', 'less': 'कम', 'natural': 'स्वाभाविक', 'original': 'उत्तर-प्रदेश', 'Greek': 'ग्रीक', 'conclude': 'सम्पन्न', 'scan': 'स्कैन', 'gynaecological': 'शक्तिन्युनता', 'some': 'कुछ', 'step': 'उठाए', 'enthusiasm': 'सैकड़ो', 'bag': 'बैग', 'Indian': 'ड्ब्ल्यू.एच.ओ.', 'immunisation': 'असेवित', 'fixed': 'हटा', 'Remember': 'याद', 'savior': 'प्राणदायक', 'Paudi': 'पौड़ी', 'Tuberculosis': 'तपेदिक', 'attempts': 'अत्याधिक', 'vaccination': 'टीकाकरण', 'cough': 'खाँसी', 'term': 'दीर्घकालीन', 'months': 'महीनों', 'Important': 'जाँचे', 'proves': 'सिद्ध', '60': '60', 'Medical': 'तैनात', 'supply': 'सप्लाई', 'hepatitis-B': 'हैपेटाइटिस-बी', 'hand': 'चेहेरे', 'centres': 'प्रशिक्षण', 'encourage': 'याद', 'head': 'सिर', 'herpes': 'हर्पिस', 'uplifts': 'उठाती', 'intoxicating': 'वस्तु', 'weapon': 'नया', 'attentiveness': 'आज्ञा', 'itching': 'चकत्तियों', 'bite': 'काटने', 'therapies': '`', 'periodic': 'मियादी', 'identifying': 'पहचानकर', 'green': 'हरी', 'throat': 'डिप्थीरिया', 'impact': 'सीधा', 'saved': 'बचाया', 'Sample': 'सैम्पल', 'disability': 'विकलांगता', 'You': 'निगरानी', 'continuous': 'लगातार', 'colleges': 'संस्थानों', 'vegetables': 'फल', 'empty': 'टायर', 'believes': 'मानना', 'damaged': 'यूरिक', 'selected': 'सा.स्वा.केन्द्र', 'alternative': 'घुटना', 'Heart': 'हृदय', 'rice': 'चावल', 'Chikungunya': 'लम्बें', 'mood': 'मूड', 'Considering': 'विषम', 'effective': 'प्रभावी', 'Contracted': 'अच्छा', 'fair': 'गहरेरंग', 'supposed': 'महामारियाँ', 'such': ';', 'sufficient': 'नाश्ते', 'rejects': 'समस्याओं', 'midwives': 'दाईयों', 'through': 'माध्यम', 'wet': 'अंडरगारमेंट', 'unacceptance': 'उपयुक्त', 'computer': 'टीवी', 'Microscopic': 'माईक्रोस्कोपिक', 'thigh': 'हड्डी', 'week': 'सप्ताह', 'species': 'प्रजाति', 'fact': 'आया', 'eating': 'पानमसाला', 'goal': 'लक्ष्य', 'sweet': 'फलों', 'ginger': ...
